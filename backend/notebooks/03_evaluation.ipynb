# %% [markdown]
# # 03. Evaluation
#
# Generates evaluation datasets from the base and fine-tuned models, computes FID vs the real dataset, and averages the CLIP score.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from ml.evaluate import evaluate, compute_fid, compute_clip_score_batch

# %% [markdown]
# ### Full Evaluation Pipeline
# This generates samples from the base model, samples from the fine-tuned model, and computes FID/CLIP automatically.

# %%
prompts = [
    "a beautiful scenic landscape, vibrant colors, detailed",
    "cinematic portrait photography, 8k, photorealistic"
]

# evaluate(
#     base_model_path="runwayml/stable-diffusion-v1-5",
#     lora_path="../models/lora_weights",
#     validation_image_dir="../../data/images",
#     prompts=prompts,
# )
