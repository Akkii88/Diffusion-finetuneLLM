# %% [markdown]
# # 02. LoRA Fine-Tuning
#
# This notebook demonstrates how to invoke the LoRA fine-tuning training script and monitor progress.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from ml.train_lora import train
import yaml

# %% [markdown]
# ### Run Training
# The training uses the configuration found in `configs/training_config.yaml`.

# %%
# Load config
with open('../configs/training_config.yaml', 'r') as f:
    config = yaml.safe_load(f)

print("Training configuration loaded. Set your dataset paths and run.")
# train(config_file='../configs/training_config.yaml')

# %% [markdown]
# To launch with Accelerate for multi-GPU or distributed settings instead of running inside this cell, use:
#
# `accelerate launch ml/train_lora.py --config configs/training_config.yaml`
