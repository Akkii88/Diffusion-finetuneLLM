# %% [markdown]
# # 01. Dataset Preparation
#
# This notebook covers downloading images from URLs, removing corrupted or duplicated images using perceptual hashing, and auto-captioning the remaining images using BLIP-2.

# %%
import os
import sys
sys.path.append(os.path.abspath('..'))

from ml.dataset import download_from_urls, generate_captions_blip2

# %% [markdown]
# ### Step 1: Download from URLs
# Replace `urls` with a list of actual image URLs representing your custom domain style.

# %%
urls = [
    # Add your image URLs here (e.g., https://example.com/image.jpg)
]
dataset_dir = "../../data/images"

# download_from_urls(urls, dataset_dir)

# %% [markdown]
# ### Step 2: Auto-captioning with BLIP-2
# This step requires a GPU to run efficiently.

# %%
# generate_captions_blip2(dataset_dir)
print("Ensure you have a GPU before uncommenting and running the above cell.")
