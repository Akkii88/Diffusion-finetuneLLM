# %% [markdown]
# # 04. Inference Demo
#
# Test your fine-tuned LoRA interactively using the InferencePipeline.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from ml.inference import InferencePipeline
import matplotlib.pyplot as plt

# %%
pipeline = InferencePipeline(
    base_model="runwayml/stable-diffusion-v1-5",
    model_path="../models/lora_weights" # Set to existing folder if LoRA is available
)

print("Loading pipeline...")
# pipeline.load()

# %%
# prompt = "A stunning highly detailed oil painting of a futuristic city at sunset"
# image = pipeline.generate_image(
#     prompt=prompt,
#     num_inference_steps=30,
#     guidance_scale=7.5,
#     scheduler="dpm++"
# )
# 
# plt.figure(figsize=(8,8))
# plt.imshow(image)
# plt.axis('off')
# plt.show()
